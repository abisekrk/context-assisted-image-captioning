# %%
import pandas as pd
import numpy as np

# %%
column_headers = ['uniq-id','image_name', 'caption','description']
all_data_dataframe = pd.read_csv('/research/nytimes_processed_data/train.tsv',  sep='\t',header = None, names = column_headers)
all_data_dataframe
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (0,1,2,3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         uniq-id                                         image_name  \
# 0             0  b53e650372e1f10e23b670d4300cef36e3979db5759054...
# 1             1  1cd63e2b35c7051a1b29b7e6c63ece51685ec0e60fd981...
# 2             2  16d730989f8c7f2222608d5b43a4c987c26d0f36af7e7a...
# 3             3  b6ebfafc6fb2c8df3c0b89c92f028703eeea4562ab0504...
# 4             4  5da6012d6d78acb71a793cf1209987681e8f59caf47af0...
# ...         ...                                                ...
# 1528791  764176  e5af0bc00d644b489eedc2977851b3e4d507a6d3210734...
# 1528792  764177  7fe5570944300c797d86040b41ede849a02c4592590991...
# 1528793  764178  8cd936ac9d726a5e206efa964f1b44401da8d6da87b0f3...
# ...

# %%
df = all_data_dataframe.drop_duplicates(subset='caption', keep="last")
df
# Out:
#         uniq-id                                         image_name  \
# 9             9  60b332a55f36ab3352e6b410efec3f1bcde44a2d10e81a...
# 10           10  ac75b94c2de33b7ed111702367d3f47cfcb17e7d8d327e...
# 86           86  e5a252ccf172f6a99ca4ac48d5a6fb20e93ba285a4dcfb...
# 234         234  ba146c5e29755de41b1657d712ab7a984e8cbb99ded3da...
# 1416       1416  fe1107b230a813f17a8bfa206eaa7a39c0fb0d085a8495...
# ...         ...                                                ...
# 1528791  764176  e5af0bc00d644b489eedc2977851b3e4d507a6d3210734...
# 1528792  764177  7fe5570944300c797d86040b41ede849a02c4592590991...
# 1528793  764178  8cd936ac9d726a5e206efa964f1b44401da8d6da87b0f3...
# 1528794  764179  36d2c4caddb81305aa6dc5edabace8611d259d2bb6ddd7...
# 1528795  764180  3436f8f67c5db6f1608e5eca0f7011168ae643f1971fa1...
#
#                                                    caption  \
# 9        Dr Diana Barnard is a member of Death With Dig...
# ...

# %%
# Train: Image - 732573
caption_list = all_data_dataframe['caption'].tolist()

# %%
# caption_list = caption_df.tolist()
print(len(caption_list))
for s in caption_list:
    print(type(s))
    if type(s) != str:
        print(s)
# Out:
# 7852
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
from PIL import Image, ImageFile

# %%
path = "/research/nytimes/downloaded_data/data/nytimes/images/015b2dd7cffa8e63155ed7b8171b62404c4707ecd3c7626e02d2d11a5243cae9.jpg"
image = Image.open(path)
image
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# /tmp/ipykernel_1366903/2282030090.py in <module>
#       1 path = "/research/nytimes/downloaded_data/data/nytimes/images/015b2dd7cffa8e63155ed7b8171b62404c4707ecd3c7626e02d2d11a5243cae9.jpg"
# ----> 2 image = Image.open(path)
#       3 image
#
# /opt/conda/lib/python3.7/site-packages/PIL/Image.py in open(fp, mode, formats)
#    3185         warnings.warn(message)
#    3186     raise UnidentifiedImageError(
# -> 3187         "cannot identify image file %r" % (filename if filename else fp)
#    3188     )
#    3189
#
# UnidentifiedImageError: cannot identify image file '/research/nytimes/downloaded_data/data/nytimes/images/015b2dd7cffa8e63155ed7b8171b62404c4707ecd3c7626e02d2d11a5243cae9.jpg'

# %%
import PIL
from pathlib import Path
from PIL import UnidentifiedImageError
from tqdm import tqdm

error_imgs = []

path = Path("/research/nytimes/downloaded_data/data/nytimes/images/").rglob("*.jpg")
for img_p in tqdm(path):
    try:
        img = PIL.Image.open(img_p)
    except PIL.UnidentifiedImageError:
            error_imgs.append(img_p)
            # print(img_p)
# Out:
# 764530it [01:47, 7083.90it/s]

# %%
print(error_imgs[0])
# Out:
# /research/nytimes/downloaded_data/data/nytimes/images/003c5b525d28e16173930d9a71d22c092e2843ed1dd9a6eab05b2cfe8cc53adf.jpg

# %%
print(len(error_imgs))
import os
for img in error_imgs:
    os.remove(img)
# Out:
# 59
